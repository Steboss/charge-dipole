# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import math
import re
import os
import seaborn as sbn
sbn.set_style("whitegrid")

import matplotlib.image as mpimg
import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#each file has:
#Rc, U_BWRF, err_BWRF, DG_BWRF, err_DG_BWRF, Ush_BWRF, err_UshBWRF, DG_shfift_BWRF, err_DGshiftBWRF
##################################################################################################
#30 A - 10 A
u_30A_10_001 = np.loadtxt("30A_box/10A/run001/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
u_30A_10_002 = np.loadtxt("30A_box/10A/run002/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")

#30 A - 12 A
u_30A_12_001 = np.loadtxt("30A_box/12A/run001/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
u_30A_12_002 = np.loadtxt("30A_box/12A/run002/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
##################################################################################################
#45 A - 10 A
u_45A_10_001 = np.loadtxt("45A_box/10A/run001/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
u_45A_10_002 = np.loadtxt("45A_box/10A/run002/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")

#45 A - 12 A
u_45A_12_001 = np.loadtxt("45A_box/12A/run001/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
u_45A_12_002 = np.loadtxt("45A_box/12A/run002/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")

#45 A - 14 A
u_45A_14_001 = np.loadtxt("45A_box/14A/run001/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
u_45A_14_002 = np.loadtxt("45A_box/14A/run002/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
##################################################################################################
#60 A - 10 A
u_60A_10_001 = np.loadtxt("60A_box/10A/run001/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
u_60A_10_002 = np.loadtxt("60A_box/10A/run002/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")

#60 A - 12 A
u_60A_12_001 = np.loadtxt("60A_box/12A/run001/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
u_60A_12_002 = np.loadtxt("60A_box/12A/run002/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")

#60 A - 14 A
u_60A_14_001 = np.loadtxt("60A_box/14A/run001/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")
u_60A_14_002 = np.loadtxt("60A_box/14A/run002/electostratics.dat",usecols=[0,1,2,3,4,5,6,7,8],delimiter=",")

# %%
color = sbn.color_palette(n_colors=14)
fig, ax = plt.subplots(figsize=(15,10))
################################################################################
#30 A box
ax.plot(u_30A_10_001[:,0],u_30A_10_001[:,1],marker="o",color=color[0],label="Box 30$\AA$, Sim-cutoff 10$\AA$")
#ax.plot(u_30A_10_002[:,0],u_30A_10_002[:,1],marker="o",color=color[0],label="long 30A 10A 002")

ax.plot(u_30A_12_001[:,0],u_30A_12_001[:,1],marker="o",color=color[1],label="Box 30$\AA$, Sim-cutoff 12$\AA$")
#ax.plot(u_30A_12_002[:,0],u_30A_12_002[:,1],marker="o",color=color[1],label="long 30A 12A 002")
################################################################################
#45 A box
#ax.plot(u_45A_10_001[:,0],u_45A_10_001[:,1],marker="o",color=color[2],label="Box 45$\AA$, Sim-cutoff 10$\AA$")
#ax.plot(u_45A_10_002[:,0],u_45A_10_002[:,1],marker="o",color=color[2],label="long 45A 10A 002")

#ax.plot(u_45A_12_001[:,0],u_45A_12_001[:,1],marker="o",color=color[3],label="Box 45$\AA$, Sim-cutoff 12$\AA$")
#ax.plot(u_45A_12_002[:,0],u_45A_12_002[:,1],marker="o",color=color[3],label="long 45A 12A 002")

#ax.plot(u_45A_14_001[:,0],u_45A_14_001[:,1],marker="o",color=color[4],label="Box 45$\AA$, Sim-cutoff 14$\AA$")
#ax.plot(u_45A_14_002[:,0],u_45A_14_002[:,1],marker="o",color=color[4],label="long 45A 14A 002")
################################################################################
#60 A box
#ax.plot(u_60A_10_001[:,0],u_60A_10_001[:,1],marker="o",color=color[5],label="Box 60$\AA$, Sim-cutoff 10$\AA$")
#ax.plot(u_60A_10_002[:,0],u_60A_10_002[:,1],marker="o",color=color[5],label="long 60A 10A 002")

#ax.plot(u_60A_12_001[:,0],u_60A_12_001[:,1],marker="o",color=color[6],label="Box 60$\AA$, Sim-cutoff 12$\AA$")
#ax.plot(u_60A_12_002[:,0],u_60A_12_002[:,1],marker="o",color=color[6],label="long 60A 12A 002")

#ax.plot(u_60A_14_001[:,0],u_60A_14_001[:,1],marker="o",color=color[7],label="Box 60$\AA$, Sim-cutoff 14$\AA$")
#ax.plot(u_60A_14_002[:,0],u_60A_14_002[:,1],marker="o",color=color[7],label="long 60A 14A 002")
################################################################################

ax.set_xlabel("R$_c$ / $\AA$",fontsize=20)
ax.set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=4, fancybox=True, shadow=True,fontsize=18)
ax.tick_params(labelsize=18)
#plt.xticks(np.arange(3, 55, 3.0))
#ax.set_xlim(0,54)#
#ax.set_ylim(-100,100)
plt.tight_layout()

# %%
#plot the free energies
color = sbn.color_palette("hls", 8)
fig, ax = plt.subplots(figsize=(15,10))
################################################################################
#30 A box
ax.plot(u_30A_10_001[:,0],u_30A_10_001[:,3],marker="o",color=color[0],label="Box 30$\AA$, Sim-cutoff 10$\AA$")
#ax.plot(u_30A_10_002[:,0],u_30A_10_002[:,3],marker="o",color=color[0],label="long 30A 10A 002")

ax.plot(u_30A_12_001[:,0],u_30A_12_001[:,3],marker="o",color=color[1],label="Box 30$\AA$, Sim-cutoff 12$\AA$")
#ax.plot(u_30A_12_002[:,0],u_30A_12_002[:,3],marker="o",color=color[1],label="long 30A 12A 002")
################################################################################
#45 A box
ax.plot(u_45A_10_001[:,0],u_45A_10_001[:,3],marker="o",color=color[2],label="Box 45$\AA$, Sim-cutoff 10$\AA$")
#ax.plot(u_45A_10_002[:,0],u_45A_10_002[:,3],marker="o",color=color[2],label="long 45A 10A 002")

ax.plot(u_45A_12_001[:,0],u_45A_12_001[:,3],marker="o",color=color[3],label="Box 45$\AA$, Sim-cutoff 12$\AA$")
#ax.plot(u_45A_12_002[:,0],u_45A_12_002[:,3],marker="o",color=color[3],label="long 45A 12A 002")

ax.plot(u_45A_14_001[:,0],u_45A_14_001[:,3],marker="o",color=color[4],label="Box 45$\AA$, Sim-cutoff 14$\AA$")
#ax.plot(u_45A_14_002[:,0],u_45A_14_002[:,3],marker="o",color=color[4],label="long 45A 14A 002")
################################################################################
#60 A box
ax.plot(u_60A_10_001[:,0],u_60A_10_001[:,3],marker="o",color=color[5],label="Box 60$\AA$, Sim-cutoff 10$\AA$")
#ax.plot(u_60A_10_002[:,0],u_60A_10_002[:,3],marker="o",color=color[5],label="long 60A 10A 002")

ax.plot(u_60A_12_001[:,0],u_60A_12_001[:,3],marker="o",color=color[6],label="Box 60$\AA$, Sim-cutoff 12$\AA$")
#ax.plot(u_60A_12_002[:,0],u_60A_12_002[:,3],marker="o",color=color[6],label="long 60A 12A 002")

ax.plot(u_60A_14_001[:,0],u_60A_14_001[:,3],marker="o",color=color[7],label="Box 60$\AA$, Sim-cutoff 14$\AA$")
#ax.plot(u_60A_14_002[:,0],u_60A_14_002[:,3],marker="o",color=color[7],label="long 60A 14A 002")
################################################################################

ax.set_xlabel("R$_c$ / $\AA$",fontsize=20)
ax.set_ylabel(r"$\langle \Delta G \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
ax.legend(loc='center', bbox_to_anchor=(0.5, 1.05),
          ncol=4, fancybox=True, shadow=True,fontsize=18)
ax.tick_params(labelsize=18)
plt.xticks(np.arange(0, 115, 5.0))
plt.yticks(np.arange(-200,15,20.0))
ax.set_xlim(0,110)#
ax.set_ylim(-200,15)
plt.tight_layout()
plt.savefig("Free_energies_plot.png",dpi=300)

# %%
#plot the free energies
color = sbn.color_palette("hls", 8)
fig, ax = plt.subplots(figsize=(15,10))
################################################################################
#30 A box
ax.errorbar(u_30A_10_001[:,0],u_30A_10_001[:,3],yerr=u_30A_10_001[:,4],marker="o",color=color[0],label="Box 30A, Sim-cutoff 10A")
#ax.plot(u_30A_10_002[:,0],u_30A_10_002[:,3],marker="o",color=color[0],label="long 30A 10A 002")

ax.errorbar(u_30A_12_001[:,0],u_30A_12_001[:,3],yerr=u_30A_12_001[:,4],marker="o",color=color[1],label="Box 30A, Sim-cutoff 12A")
#ax.plot(u_30A_12_002[:,0],u_30A_12_002[:,3],marker="o",color=color[1],label="long 30A 12A 002")
################################################################################
#45 A box
ax.errorbar(u_45A_10_001[:,0],u_45A_10_001[:,3],yerr=u_45A_10_001[:,4],marker="o",color=color[2],label="Box 45A, Sim-cutoff 10A")
#ax.plot(u_45A_10_002[:,0],u_45A_10_002[:,3],marker="o",color=color[2],label="long 45A 10A 002")

ax.errorbar(u_45A_12_001[:,0],u_45A_12_001[:,3],yerr=u_45A_12_001[:,4],marker="o",color=color[3],label="Box 45A, Sim-cutoff 12A")
#ax.plot(u_45A_12_002[:,0],u_45A_12_002[:,3],marker="o",color=color[3],label="long 45A 12A 002")

ax.errorbar(u_45A_14_001[:,0],u_45A_14_001[:,3],yerr=u_45A_14_001[:,4],marker="o",color=color[4],label="Box 45A, Sim-cutoff 14A")
#ax.plot(u_45A_14_002[:,0],u_45A_14_002[:,3],marker="o",color=color[4],label="long 45A 14A 002")
################################################################################
#60 A box
ax.errorbar(u_60A_10_001[:,0],u_60A_10_001[:,3],yerr=u_60A_10_001[:,4],marker="o",color=color[5],label="Box 60A, Sim-cutoff 10A")
#ax.plot(u_60A_10_002[:,0],u_60A_10_002[:,3],marker="o",color=color[5],label="long 60A 10A 002")

ax.errorbar(u_60A_12_001[:,0],u_60A_10_001[:,3],yerr=u_60A_10_001[:,4],marker="o",color=color[6],label="Box 60A, Sim-cutoff 12A")
#ax.plot(u_60A_12_002[:,0],u_60A_12_002[:,3],marker="o",color=color[6],label="long 60A 12A 002")

ax.errorbar(u_60A_14_001[:,0],u_60A_14_001[:,3],yerr=u_60A_14_001[:,4],marker="o",color=color[7],label="Box 60A, Sim-cutoff 14A")
#ax.plot(u_60A_14_002[:,0],u_60A_14_002[:,3],marker="o",color=color[7],label="long 60A 14A 002")
################################################################################

ax.set_xlabel("R$_c$ / $\AA$",fontsize=20)
ax.set_ylabel(r"$\left \langle \Delta G \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
ax.legend(loc='center', bbox_to_anchor=(0.5, 1.05),
          ncol=4, fancybox=True, shadow=True,fontsize=18)
ax.tick_params(labelsize=18)
plt.xticks(np.arange(0, 115, 5.0))
ax.set_xlim(0,110)#
ax.set_ylim(-200,15)
plt.tight_layout()

# %%
#SHIFTED DG
#plot the free energies
color = sbn.color_palette(n_colors=14)
fig, ax = plt.subplots(figsize=(15,10))
################################################################################
#30 A box
ax.plot(u_30A_10_001[:,0],u_30A_10_001[:,7],marker="o",color=color[0],label="long 30A 10A 001")
ax.plot(u_30A_10_002[:,0],u_30A_10_002[:,7],marker="o",color=color[0],label="long 30A 10A 002")

ax.plot(u_30A_12_001[:,0],u_30A_12_001[:,7],marker="o",color=color[1],label="long 30A 12A 001")
ax.plot(u_30A_12_002[:,0],u_30A_12_002[:,7],marker="o",color=color[1],label="long 30A 12A 002")
################################################################################
#45 A box
ax.plot(u_45A_10_001[:,0],u_45A_10_001[:,7],marker="o",color=color[2],label="long 45A 10A 001")
#ax.plot(u_45A_10_002[:,0],u_45A_10_002[:,7],marker="o",color=color[2],label="long 45A 10A 002")

ax.plot(u_45A_12_001[:,0],u_45A_12_001[:,7],marker="o",color=color[3],label="long 45A 12A 001")
#ax.plot(u_45A_12_002[:,0],u_45A_12_002[:,7],marker="o",color=color[3],label="long 45A 12A 002")

ax.plot(u_45A_14_001[:,0],u_45A_14_001[:,7],marker="o",color=color[4],label="long 45A 14A 001")
ax.plot(u_45A_14_002[:,0],u_45A_14_002[:,7],marker="o",color=color[4],label="long 45A 14A 002")
################################################################################
#60 A box
ax.plot(u_60A_10_001[:,0],u_60A_10_001[:,7],marker="o",color=color[5],label="long 60A 10A 001")
ax.plot(u_60A_10_002[:,0],u_60A_10_002[:,7],marker="o",color=color[5],label="long 60A 10A 002")

ax.plot(u_60A_12_001[:,0],u_60A_12_001[:,7],marker="o",color=color[6],label="long 60A 12A 001")
ax.plot(u_60A_12_002[:,0],u_60A_12_002[:,7],marker="o",color=color[6],label="long 60A 12A 002")

ax.plot(u_60A_14_001[:,0],u_60A_14_001[:,7],marker="o",color=color[7],label="long 60A 14A 001")
ax.plot(u_60A_14_002[:,0],u_60A_14_002[:,7],marker="o",color=color[7],label="long 60A 14A 002")
################################################################################

ax.set_xlabel("r / $\AA$",fontsize=20)
ax.set_ylabel(r"$\left \langle \Delta G \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
ax.legend(loc='center', bbox_to_anchor=(0.5, 1.05),
          ncol=7, fancybox=True, shadow=True,fontsize=18)
ax.tick_params(labelsize=18)
#plt.xticks(np.arange(3, 55, 3.0))
#ax.set_xlim(0,54)#
#ax.set_ylim(0,200)
plt.tight_layout()

# %%
#plot the free energies
color = sbn.color_palette(n_colors=14)
fig, ax = plt.subplots(figsize=(15,10))
#BWRF
#30 A box
ax.plot(u_30A_10_001[:,0],u_30A_10_001[:,3],marker="o",color=color[0],label="long 30A 10A 001")
ax.plot(u_30A_10_002[:,0],u_30A_10_002[:,3],marker="o",color=color[0],label="long 30A 10A 002")

ax.plot(u_30A_12_001[:,0],u_30A_12_001[:,3],marker="o",color=color[0],label="long 30A 12A 001")
ax.plot(u_30A_12_002[:,0],u_30A_12_002[:,3],marker="o",color=color[0],label="long 30A 12A 002")
################################################################################
#45 A box
ax.plot(u_45A_10_001[:,0],u_45A_10_001[:,3],marker="o",color=color[0],label="long 45A 10A 001")
#ax.plot(u_45A_10_002[:,0],u_45A_10_002[:,3],marker="o",color=color[0],label="long 45A 10A 002")

ax.plot(u_45A_12_001[:,0],u_45A_12_001[:,3],marker="o",color=color[0],label="long 45A 12A 001")
#ax.plot(u_45A_12_002[:,0],u_45A_12_002[:,3],marker="o",color=color[0],label="long 45A 12A 002")

ax.plot(u_45A_14_001[:,0],u_45A_14_001[:,3],marker="o",color=color[0],label="long 45A 14A 001")
ax.plot(u_45A_14_002[:,0],u_45A_14_002[:,3],marker="o",color=color[0],label="long 45A 14A 002")
################################################################################
#60 A box
ax.plot(u_60A_10_001[:,0],u_60A_10_001[:,3],marker="o",color=color[0],label="long 60A 10A 001")
ax.plot(u_60A_10_002[:,0],u_60A_10_002[:,3],marker="o",color=color[0],label="long 60A 10A 002")

ax.plot(u_60A_12_001[:,0],u_60A_12_001[:,3],marker="o",color=color[0],label="long 60A 12A 001")
ax.plot(u_60A_12_002[:,0],u_60A_12_002[:,3],marker="o",color=color[0],label="long 60A 12A 002")

ax.plot(u_60A_14_001[:,0],u_60A_14_001[:,3],marker="o",color=color[0],label="long 60A 14A 001")
ax.plot(u_60A_14_002[:,0],u_60A_14_002[:,3],marker="o",color=color[0],label="long 60A 14A 002")

#SHIFTED
################################################################################
#30 A box
ax.plot(u_30A_10_001[:,0],u_30A_10_001[:,7],marker="o",color=color[1],label="long 30A 10A 001")
ax.plot(u_30A_10_002[:,0],u_30A_10_002[:,7],marker="o",color=color[1],label="long 30A 10A 002")

ax.plot(u_30A_12_001[:,0],u_30A_12_001[:,7],marker="o",color=color[1],label="long 30A 12A 001")
ax.plot(u_30A_12_002[:,0],u_30A_12_002[:,7],marker="o",color=color[1],label="long 30A 12A 002")
################################################################################
#45 A box
ax.plot(u_45A_10_001[:,0],u_45A_10_001[:,7],marker="o",color=color[1],label="long 45A 10A 001")
#ax.plot(u_45A_10_002[:,0],u_45A_10_002[:,7],marker="o",color=color[1],label="long 45A 10A 002")

ax.plot(u_45A_12_001[:,0],u_45A_12_001[:,7],marker="o",color=color[1],label="long 45A 12A 001")
#ax.plot(u_45A_12_002[:,0],u_45A_12_002[:,7],marker="o",color=color[1],label="long 45A 12A 002")

ax.plot(u_45A_14_001[:,0],u_45A_14_001[:,7],marker="o",color=color[1],label="long 45A 14A 001")
ax.plot(u_45A_14_002[:,0],u_45A_14_002[:,7],marker="o",color=color[1],label="long 45A 14A 002")
################################################################################
#60 A box
ax.plot(u_60A_10_001[:,0],u_60A_10_001[:,7],marker="o",color=color[1],label="long 60A 10A 001")
ax.plot(u_60A_10_002[:,0],u_60A_10_002[:,7],marker="o",color=color[1],label="long 60A 10A 002")

ax.plot(u_60A_12_001[:,0],u_60A_12_001[:,7],marker="o",color=color[1],label="long 60A 12A 001")
ax.plot(u_60A_12_002[:,0],u_60A_12_002[:,7],marker="o",color=color[1],label="long 60A 12A 002")

ax.plot(u_60A_14_001[:,0],u_60A_14_001[:,7],marker="o",color=color[1],label="long 60A 14A 001")
ax.plot(u_60A_14_002[:,0],u_60A_14_002[:,7],marker="o",color=color[1],label="long 60A 14A 002")
################################################################################

ax.set_xlabel("r / $\AA$",fontsize=20)
ax.set_ylabel(r"$\left \langle \Delta G \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax.legend(loc='center', bbox_to_anchor=(0.5, 1.05),
#          ncol=7, fancybox=True, shadow=True,fontsize=18)
ax.tick_params(labelsize=18)
#plt.xticks(np.arange(3, 55, 3.0))
#ax.set_xlim(0,54)#
#ax.set_ylim(0,200)
plt.tight_layout()
