# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib as mpl
from numpy import *
import math
import re
import os
import seaborn as sbn
sbn.set_style("whitegrid")

import matplotlib.image as mpimg
import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
def extract_potential(folders):
    
    results = {}

    for ifolder in folders:
        #e.g.  l_0.56,0_deg/computed.csv
        #file computed.csv
        #extract the angle
        distance = []
        pots = []
        deg = ifolder.split("/")[0].split("_")[0]
      
        reader = open(ifolder,"r").readlines()
        for read in reader:
            r = float(read.split(",")[0])
            pot = float(read.split(",")[1])
            distance.append(r)
            pots.append(pot)
            
        results[deg] = [ distance, pots ]
        #so results[deg][0] wil be distances and results[deg][1] potential
        
    
    return results

# %%
#Rotationally-averaged charge-dipole potential in a reaction field
#Functional form:
#(-4/3*kT)*(qu/4pieps0*r**2)**2 * ( (esp1 + esp2)**2 + (r**3/a**3)*eps1*(eps1*(r**3/a**3 - 2) - 2*eps2) ) 
computed  = extract_potential(glob.glob("*_deg/computed.dat"))
theory = extract_potential(glob.glob("*_deg/theory.dat"))

# %%
#plot
color = sbn.color_palette()
fig, ax = plt.subplots(2,3,figsize=(15,8))

#0
ax[0,0].plot(computed['0'][0],computed['0'][1],color=color[0],marker="o",label="Computed - 0 deg")
ax[0,0].plot(theory['0'][0],theory['0'][1],color=color[1],marker="o",label="Theory - 0 deg")
ax[0,0].set_xlabel("r / $\AA$",fontsize=20)
ax[0,0].legend(loc="best",fontsize=20)
ax[0,0].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)

#30
ax[0,1].plot(computed['30'][0],computed['30'][1],color=color[0],marker="o",label="Computed - 30 deg")
ax[0,1].plot(theory['30'][0],theory['30'][1],color=color[1],marker="o",label="Theory - 30 deg")
ax[0,1].set_xlabel("r / $\AA$",fontsize=20)
ax[0,1].legend(loc="best",fontsize=20)
ax[0,1].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)


#60
ax[0,2].plot(computed['60'][0],computed['60'][1],color=color[0],marker="o",label="Computed - 60 deg")
ax[0,2].plot(theory['60'][0],theory['60'][1],color=color[1],marker="o",label="Theory - 60 deg")
ax[0,2].set_xlabel("r / $\AA$",fontsize=20)
ax[0,2].legend(loc="best",fontsize=20)
ax[0,2].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)

#90
ax[1,0].plot(computed['90'][0],computed['90'][1],color=color[0],marker="o",label="Computed - 90 deg")
ax[1,0].plot(theory['90'][0],theory['90'][1],color=color[1],marker="o",label="Theory - 90 deg")
ax[1,0].set_xlabel("r / $\AA$",fontsize=20)
ax[1,0].legend(loc="best",fontsize=20)
ax[1,0].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)


#120
ax[1,1].plot(computed['120'][0],computed['120'][1],color=color[0],marker="o",label="Computed - 120 deg")
ax[1,1].plot(theory['120'][0],theory['120'][1],color=color[1],marker="o",label="Theory - 120 deg")
ax[1,1].set_xlabel("r / $\AA$",fontsize=20)
ax[1,1].legend(loc="best",fontsize=20)
ax[1,1].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)

#150
ax[1,2].plot(computed['150'][0],computed['150'][1],color=color[0],marker="o",label="Computed - 150 deg")
ax[1,2].plot(theory['150'][0],theory['150'][1],color=color[1],marker="o",label="Theory - 150 deg")
ax[1,2].set_xlabel("r / $\AA$",fontsize=20)
ax[1,2].legend(loc="best",fontsize=20)
ax[1,2].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)
plt.tight_layout()

# %%
def natural_sort(list_to_sort):
    """Function to sort a list in a natural order"""
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)',key)]

    return sorted(list_to_sort,key=alphanum_key)


#compute the differences between the two curves, once the difference is less then 0.01kcal/mol print out the distsance
results = {}

keys = []
for key in computed.keys():
    keys.append(key)
    
keys = natural_sort(keys)


for key in keys:
    #print("####")
    #print(key)
    #print("####")
    for i,pots in enumerate(computed[key][1],0):
        diff = pots - theory[key][1][i]
        #print(diff)
        if abs(diff)<0.01:
            results[key] = [computed[key][0][i]]
            break
            
            
for key in keys:
    print("Angle %.4f distance: %.4f" % (float(key),float(results[key][0])))
    

elem = "93"
for i,pots in enumerate(computed[elem][1],0):
    diff = pots -theory[elem][1][i]
    if diff < 0.01:
        print(computed[elem][0][i])
# Out:
# Angle 0.0000 distance: 10.9091
# Angle 3.0000 distance: 10.9091
# Angle 6.0000 distance: 10.9091
# Angle 9.0000 distance: 10.9091
# Angle 12.0000 distance: 10.6364
# Angle 15.0000 distance: 10.6364
# Angle 18.0000 distance: 10.3636
# Angle 21.0000 distance: 10.3636
# Angle 24.0000 distance: 10.0909
# Angle 27.0000 distance: 9.8182
# Angle 30.0000 distance: 9.5455
# Angle 33.0000 distance: 9.2727
# Angle 36.0000 distance: 9.0000
# Angle 39.0000 distance: 8.7273
# Angle 42.0000 distance: 8.1818
# Angle 45.0000 distance: 7.9091
# Angle 48.0000 distance: 7.3636
# Angle 51.0000 distance: 7.0909
# Angle 54.0000 distance: 6.5455
# Angle 57.0000 distance: 6.0000
# Angle 60.0000 distance: 5.7273
# Angle 63.0000 distance: 5.1818
# Angle 66.0000 distance: 4.6364
# Angle 69.0000 distance: 23.1818
# Angle 72.0000 distance: 21.5455
# Angle 75.0000 distance: 19.6364
# Angle 78.0000 distance: 17.7273
# Angle 81.0000 distance: 15.2727
# Angle 84.0000 distance: 12.5455
# Angle 87.0000 distance: 9.0000
# Angle 90.0000 distance: 3.0000
# Angle 93.0000 distance: 9.0000
# Angle 96.0000 distance: 12.5455
# Angle 99.0000 distance: 15.2727
# Angle 102.0000 distance: 17.7273
# Angle 105.0000 distance: 19.6364
# Angle 108.0000 distance: 21.5455
# Angle 111.0000 distance: 23.1818
# Angle 114.0000 distance: 4.6364
# Angle 117.0000 distance: 5.1818
# Angle 120.0000 distance: 5.7273
# Angle 123.0000 distance: 6.0000
# Angle 126.0000 distance: 6.5455
# Angle 129.0000 distance: 7.0909
# Angle 132.0000 distance: 7.3636
# Angle 135.0000 distance: 7.9091
# Angle 138.0000 distance: 8.1818
# Angle 141.0000 distance: 8.7273
# Angle 144.0000 distance: 9.0000
# Angle 147.0000 distance: 9.2727
# Angle 150.0000 distance: 9.5455
# Angle 153.0000 distance: 9.8182
# Angle 156.0000 distance: 10.0909
# Angle 159.0000 distance: 10.3636
# Angle 162.0000 distance: 10.3636
# Angle 165.0000 distance: 10.6364
# Angle 168.0000 distance: 10.6364
# Angle 171.0000 distance: 10.9091
# Angle 174.0000 distance: 10.9091
# Angle 177.0000 distance: 10.9091
# Angle 180.0000 distance: 10.9091
# Angle 183.0000 distance: 10.9091
# Angle 186.0000 distance: 10.9091
# Angle 189.0000 distance: 10.9091
# Angle 192.0000 distance: 10.6364
# Angle 195.0000 distance: 10.6364
# Angle 198.0000 distance: 10.3636
# Angle 201.0000 distance: 10.3636
# Angle 204.0000 distance: 10.0909
# Angle 207.0000 distance: 9.8182
# Angle 210.0000 distance: 9.5455
# Angle 213.0000 distance: 9.2727
# Angle 216.0000 distance: 9.0000
# Angle 219.0000 distance: 8.7273
# Angle 222.0000 distance: 8.1818
# Angle 225.0000 distance: 7.9091
# Angle 228.0000 distance: 7.3636
# Angle 231.0000 distance: 7.0909
# Angle 234.0000 distance: 6.5455
# Angle 237.0000 distance: 6.0000
# Angle 240.0000 distance: 5.7273
# Angle 243.0000 distance: 5.1818
# Angle 246.0000 distance: 4.6364
# Angle 249.0000 distance: 23.1818
# Angle 252.0000 distance: 21.5455
# Angle 255.0000 distance: 19.6364
# Angle 258.0000 distance: 17.7273
# Angle 261.0000 distance: 15.2727
# Angle 264.0000 distance: 12.5455
# Angle 267.0000 distance: 9.0000
# Angle 270.0000 distance: 3.0000
# Angle 273.0000 distance: 9.0000
# Angle 276.0000 distance: 12.5455
# Angle 279.0000 distance: 15.2727
# Angle 282.0000 distance: 17.7273
# Angle 285.0000 distance: 19.6364
# Angle 288.0000 distance: 21.5455
# Angle 291.0000 distance: 23.1818
# Angle 294.0000 distance: 4.6364
# Angle 297.0000 distance: 5.1818
# Angle 300.0000 distance: 5.7273
# Angle 303.0000 distance: 6.0000
# Angle 306.0000 distance: 6.5455
# Angle 309.0000 distance: 7.0909
# Angle 312.0000 distance: 7.3636
# Angle 315.0000 distance: 7.9091
# Angle 318.0000 distance: 8.1818
# Angle 321.0000 distance: 8.7273
# Angle 324.0000 distance: 9.0000
# Angle 327.0000 distance: 9.2727
# Angle 330.0000 distance: 9.5455
# Angle 333.0000 distance: 9.8182
# Angle 336.0000 distance: 10.0909
# Angle 339.0000 distance: 10.3636
# Angle 342.0000 distance: 10.3636
# Angle 345.0000 distance: 10.6364
# Angle 348.0000 distance: 10.6364
# Angle 351.0000 distance: 10.9091
# Angle 354.0000 distance: 10.9091
# Angle 357.0000 distance: 10.9091
# Angle 360.0000 distance: 10.9091
# 3.0
# 3.2727
# 3.5455
# 3.8182
# 4.0909
# 4.3636
# 4.6364
# 4.9091
# 5.1818
# 5.4545
# 5.7273
# 6.0
# 6.2727
# 6.5455
# 6.8182
# 7.0909
# 7.3636
# 7.6364
# 7.9091
# 8.1818
# 8.4545
# 8.7273
# 9.0
# 9.2727
# 9.5455
# 9.8182
# 10.0909
# 10.3636
# 10.6364
# 10.9091
# 11.1818
# 11.4545
# 11.7273
# 12.0
# 12.2727
# 12.5455
# 12.8182
# 13.0909
# 13.3636
# 13.6364
# 13.9091
# 14.1818
# 14.4545
# 14.7273
# 15.0
# 15.2727
# 15.5455
# 15.8182
# 16.0909
# 16.3636
# 16.6364
# 16.9091
# 17.1818
# 17.4545
# 17.7273
# 18.0
# 18.2727
# 18.5455
# 18.8182
# 19.0909
# 19.3636
# 19.6364
# 19.9091
# 20.1818
# 20.4545
# 20.7273
# 21.0
# 21.2727
# 21.5455
# 21.8182
# 22.0909
# 22.3636
# 22.6364
# 22.9091
# 23.1818
# 23.4545
# 23.7273
# 24.0
# 24.2727
# 24.5455
# 24.8182
# 25.0909
# 25.3636
# 25.6364
# 25.9091
# 26.1818
# 26.4545
# 26.7273
# 27.0
# 27.2727
# 27.5455
# 27.8182
# 28.0909
# 28.3636
# 28.6364
# 28.9091
# 29.1818
# 29.4545
# 29.7273
# 30.0
