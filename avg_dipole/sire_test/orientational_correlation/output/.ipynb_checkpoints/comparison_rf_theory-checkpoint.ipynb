# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib as mpl
from numpy import *
import math
import re
import os
import seaborn as sbn
sbn.set_style("whitegrid")

import matplotlib.image as mpimg
import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
def extract_potential(folders):
    
    results = {}

    for ifolder in folders:
        #e.g.  l_0.56,0_deg/computed.csv
        #file computed.csv
        #extract the angle
        distance = []
        pots = []
        deg = ifolder.split("/")[0].split("_")[0]
      
        reader = open(ifolder,"r").readlines()
        for read in reader:
            r = float(read.split(",")[0])
            pot = float(read.split(",")[1])
            distance.append(r)
            pots.append(pot)
            
        results[deg] = [ distance, pots ]
        #so results[deg][0] wil be distances and results[deg][1] potential
        
    
    return results

# %%
shells = np.linspace(3,55,52)
energies = [-5.5732,1.5044,0.3667,0.1931,0.2525,0.1603,0.1288, 0.0952]
COMPUTED Shell 3  nrg -5.5732 +/- 1.1592
COMPUTED Shell 4  nrg 1.5044 +/- 1.8745
COMPUTED Shell 5  nrg 0.3667 +/- 0.3692
COMPUTED Shell 6  nrg 0.1931 +/- 0.2281
COMPUTED Shell 7  nrg 0.2525 +/- 0.1166
COMPUTED Shell 8  nrg 0.1603 +/- 0.0674
COMPUTED Shell 9  nrg 0.1288 +/- 0.0409
COMPUTED Shell 10  nrg 0.0952 +/- 0.0276
COMPUTED Shell 11  nrg 0.0794 +/- 0.0179
COMPUTED Shell 12  nrg 0.0577 +/- 0.0129
COMPUTED Shell 13  nrg 0.0481 +/- 0.0093
COMPUTED Shell 14  nrg 0.0392 +/- 0.0070
COMPUTED Shell 15  nrg 0.0315 +/- 0.0052
COMPUTED Shell 16  nrg 0.0268 +/- 0.0041
COMPUTED Shell 17  nrg 0.0221 +/- 0.0032
COMPUTED Shell 18  nrg 0.0187 +/- 0.0026
COMPUTED Shell 19  nrg 0.0162 +/- 0.0021
COMPUTED Shell 20  nrg 0.0138 +/- 0.0017
COMPUTED Shell 21  nrg 0.0120 +/- 0.0014
COMPUTED Shell 22  nrg 0.0105 +/- 0.0012
COMPUTED Shell 23  nrg 0.0092 +/- 0.0010
COMPUTED Shell 24  nrg 0.0081 +/- 0.0008
COMPUTED Shell 25  nrg 0.0072 +/- 0.0007
COMPUTED Shell 26  nrg 0.0064 +/- 0.0006
COMPUTED Shell 27  nrg 0.0057 +/- 0.0005
COMPUTED Shell 28  nrg 0.0052 +/- 0.0005
COMPUTED Shell 29  nrg 0.0046 +/- 0.0004
COMPUTED Shell 30  nrg 0.0042 +/- 0.0004
COMPUTED Shell 31  nrg 0.0038 +/- 0.0003
COMPUTED Shell 32  nrg 0.0036 +/- 0.0003
COMPUTED Shell 33  nrg 0.0033 +/- 0.0003
COMPUTED Shell 34  nrg 0.0030 +/- 0.0003
COMPUTED Shell 35  nrg 0.0027 +/- 0.0002
COMPUTED Shell 36  nrg 0.0025 +/- 0.0002
COMPUTED Shell 37  nrg 0.0023 +/- 0.0002
COMPUTED Shell 38  nrg 0.0022 +/- 0.0002
COMPUTED Shell 39  nrg 0.0020 +/- 0.0002
COMPUTED Shell 40  nrg 0.0019 +/- 0.0002
COMPUTED Shell 41  nrg 0.0018 +/- 0.0002
COMPUTED Shell 42  nrg 0.0017 +/- 0.0002
COMPUTED Shell 43  nrg 0.0016 +/- 0.0002
COMPUTED Shell 44  nrg 0.0015 +/- 0.0002
COMPUTED Shell 45  nrg 0.0014 +/- 0.0003
COMPUTED Shell 46  nrg 0.0013 +/- 0.0003
COMPUTED Shell 47  nrg 0.0013 +/- 0.0003
COMPUTED Shell 48  nrg 0.0012 +/- 0.0004
COMPUTED Shell 49  nrg 0.0011 +/- 0.0005
COMPUTED Shell 50  nrg 0.0011 +/- 0.0006
COMPUTED Shell 51  nrg 0.0011 +/- 0.0008
COMPUTED Shell 52  nrg 0.0012 +/- 0.0012
COMPUTED Shell 53  nrg 0.0013 +/- 0.0018
COMPUTED Shell 54  nrg 0.0021 +/- 0.0017
COMPUTED Shell 55  nrg 0.0027 +/- 0.0012

# %%
#plot
color = sbn.color_palette()
fig, ax = plt.subplots(4,3,figsize=(25,20))

#0
ax[0,0].plot(computed['0'][0],computed['0'][1],color=color[0],marker="o",label="Computed - 0 deg")
ax[0,0].plot(theory['0'][0],theory['0'][1],color=color[1],marker="o",label="Theory - 0 deg")
ax[0,0].set_xlabel("r / $\AA$",fontsize=20)
ax[0,0].legend(loc="best",fontsize=20)
ax[0,0].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)

#30
ax[0,1].plot(computed['30'][0],computed['30'][1],color=color[0],marker="o",label="Computed - 30 deg")
ax[0,1].plot(theory['30'][0],theory['30'][1],color=color[1],marker="o",label="Theory - 30 deg")
ax[0,1].set_xlabel("r / $\AA$",fontsize=20)
ax[0,1].legend(loc="best",fontsize=20)
ax[0,1].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
ax[0,1].set_xlim(10,30)
ax[0,1].set_ylim(0,0.5)


#60
ax[0,2].plot(computed['60'][0],computed['60'][1],color=color[0],marker="o",label="Computed - 60 deg")
ax[0,2].plot(theory['60'][0],theory['60'][1],color=color[1],marker="o",label="Theory - 60 deg")
ax[0,2].set_xlabel("r / $\AA$",fontsize=20)
ax[0,2].legend(loc="best",fontsize=20)
ax[0,2].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
ax[0,2].set_xlim(10,30)
ax[0,2].set_ylim(0,0.5)
#90
ax[1,0].plot(computed['90'][0],computed['90'][1],color=color[0],marker="o",label="Computed - 90 deg")
ax[1,0].plot(theory['90'][0],theory['90'][1],color=color[1],marker="o",label="Theory - 90 deg")
ax[1,0].set_xlabel("r / $\AA$",fontsize=20)
ax[1,0].legend(loc="best",fontsize=20)
ax[1,0].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)


#120
ax[1,1].plot(computed['120'][0],computed['120'][1],color=color[0],marker="o",label="Computed - 120 deg")
ax[1,1].plot(theory['120'][0],theory['120'][1],color=color[1],marker="o",label="Theory - 120 deg")
ax[1,1].set_xlabel("r / $\AA$",fontsize=20)
ax[1,1].legend(loc="best",fontsize=20)
ax[1,1].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)

#150
ax[1,2].plot(computed['150'][0],computed['150'][1],color=color[0],marker="o",label="Computed - 150 deg")
ax[1,2].plot(theory['150'][0],theory['150'][1],color=color[1],marker="o",label="Theory - 150 deg")
ax[1,2].set_xlabel("r / $\AA$",fontsize=20)
ax[1,2].legend(loc="best",fontsize=20)
ax[1,2].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)
plt.tight_layout()

#180
ax[2,0].plot(computed['180'][0],computed['180'][1],color=color[0],marker="o",label="Computed - 180 deg")
ax[2,0].plot(theory['180'][0],theory['180'][1],color=color[1],marker="o",label="Theory - 180 deg")
ax[2,0].set_xlabel("r / $\AA$",fontsize=20)
ax[2,0].legend(loc="best",fontsize=20)
ax[2,0].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)
plt.tight_layout()

#210
ax[2,1].plot(computed['210'][0],computed['210'][1],color=color[0],marker="o",label="Computed - 210 deg")
ax[2,1].plot(theory['210'][0],theory['210'][1],color=color[1],marker="o",label="Theory - 210 deg")
ax[2,1].set_xlabel("r / $\AA$",fontsize=20)
ax[2,1].legend(loc="best",fontsize=20)
ax[2,1].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)
plt.tight_layout()

#240
ax[2,2].plot(computed['240'][0],computed['240'][1],color=color[0],marker="o",label="Computed - 240 deg")
ax[2,2].plot(theory['240'][0],theory['240'][1],color=color[1],marker="o",label="Theory - 240 deg")
ax[2,2].set_xlabel("r / $\AA$",fontsize=20)
ax[2,2].legend(loc="best",fontsize=20)
ax[2,2].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)
plt.tight_layout()


#270
ax[3,0].plot(computed['270'][0],computed['270'][1],color=color[0],marker="o",label="Computed - 270 deg")
ax[3,0].plot(theory['270'][0],theory['270'][1],color=color[1],marker="o",label="Theory - 270 deg")
ax[3,0].set_xlabel("r / $\AA$",fontsize=20)
ax[3,0].legend(loc="best",fontsize=20)
ax[3,0].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)
plt.tight_layout()

#300
ax[3,1].plot(computed['300'][0],computed['300'][1],color=color[0],marker="o",label="Computed - 300 deg")
ax[3,1].plot(theory['300'][0],theory['300'][1],color=color[1],marker="o",label="Theory - 300 deg")
ax[3,1].set_xlabel("r / $\AA$",fontsize=20)
ax[3,1].legend(loc="best",fontsize=20)
ax[3,1].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)
plt.tight_layout()

#330
ax[3,2].plot(computed['330'][0],computed['330'][1],color=color[0],marker="o",label="Computed - 330 deg")
ax[3,2].plot(theory['330'][0],theory['330'][1],color=color[1],marker="o",label="Theory - 330 deg")
ax[3,2].set_xlabel("r / $\AA$",fontsize=20)
ax[3,2].legend(loc="best",fontsize=20)
ax[3,2].set_ylabel(r"$\left \langle V(r) \right \rangle$ / kcal$\cdot$mol$^{-1}$" ,fontsize=20)
#ax[0,0].set_xlim(10,30)
#ax[0,0].set_ylim(0,0.5)
plt.tight_layout()

# %%
def natural_sort(list_to_sort):
    """Function to sort a list in a natural order"""
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)',key)]

    return sorted(list_to_sort,key=alphanum_key)


#compute the differences between the two curves, once the difference is less then 0.01kcal/mol print out the distsance
results = {}

keys = []
for key in computed.keys():
    keys.append(key)
    
keys = natural_sort(keys)

differences = {}
for key in keys:
    differences[key] = {}
    diffs = []
    for i,pots in enumerate(computed[key][1],0):
        
        diff = pots - theory[key][1][i]
        diffs.append(diff)#
        
        if abs(diff)<0.01:
            #print(computed[key][0][i])
            starting_val = i 
            t = i 
            for val in computed[key][1][starting_val:]:
                cont_diff = val - theory[key][1][t]
                
                if abs(cont_diff)<0.01:
                    t+=1
                else:
                    break
            
            
        if len(computed[key][1][starting_val:]) - t ==0:
            results[key] = [computed[key][0][starting_val]]
        else:
            break
                
        
#Basically, the water and the theory coincides till a point then  the agreement is broken

# %%
results
# Out:
# {}
